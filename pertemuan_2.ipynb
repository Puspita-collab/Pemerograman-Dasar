# %% [markdown]
# <a href="https://colab.research.google.com/github/Puspita-collab/Pemerograman-Dasar/blob/main/pertemuan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jawaban latihan 1
tegangan_panel = 18
arus_panel = 6
jenis_sel = "monocrystalline"

print (tegangan_panel, arus_panel, jenis_sel)
# Out:
# 18 6 monocrystalline

# %%
# Jawaban latihan 2
tegangan = 48.5
jumlah_panel = 240
sedang_beroperasi = True
nama_komponen = "panel surya"

print(tegangan, type(tegangan))
print(jumlah_panel, type(jumlah_panel))
print(sedang_beroperasi, type(sedang_beroperasi))
print(nama_komponen, type(nama_komponen))
# Out:
# 48.5 <class 'float'>
# 240 <class 'int'>
# True <class 'bool'>
# panel surya <class 'str'>

# %%
# Jawaban latihan 3
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
# Jawaban latihan 4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

#(a) cetak pembacaan pertama dan terakhir
print("pembacaan pertama:", tegangan_harian[0])
print("pembacaan terakhir:", tegangan_harian[-1])

#(b) tambahkan pembacaan baru
tegangan_harian.append(222.0)
print("data setelah ditambahkan:", tegangan_harian)

#(c) cetak jumlah total data
print("jumlah total data:", len(tegangan_harian))
# Out:
# pembacaan pertama: 217.5
# pembacaan terakhir: 216.9
# data setelah ditambahkan: [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# jumlah total data: 7

# %%
# Jawaban latihan 5
motor = {"nama": "Motor induksi 3 Fasa",
         "daya_kw": 5.5,
         "tegangan_v": 380,
         "rpm": 1500
         }

#cetak salah satu nilai
print("nama motor:", motor["nama"])

#ubah nilai rpm
motor["rpm"] = 1450

#cetak seluruh dictionary
print("data motor setelah diubah:")
print(motor)
# Out:
# nama motor: Motor induksi 3 Fasa
# data motor setelah diubah:
# {'nama': 'Motor induksi 3 Fasa', 'daya_kw': 5.5, 'tegangan_v': 380, 'rpm': 1450}

# %%
# Jawaban latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80, "status": "pemeliharaan"},
]

# Cetak nama unit kedua
print("Nama unit kedua:", pembangkit[1]["nama"])

# Ubah status salah satu unit
pembangkit[0]["status"] = "pemeliharaan"

# Tambahkan satu unit baru
pembangkit.append({
    "nama": "Unit-4",
    "kapasitas_MW": 120,
    "status": "operasi"
})

# Cetak seluruh data
print("\nData seluruh pembangkit:")
print(pembangkit)
# Out:
# Nama unit kedua: Unit-2
#
# Data seluruh pembangkit:
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'pemeliharaan'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}, {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}]
